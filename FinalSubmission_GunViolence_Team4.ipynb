# %% [markdown]
# <a href="https://colab.research.google.com/github/strivedi2/Gun-Violence-in-United-States/blob/master/FinalSubmission_GunViolence_Team4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gun Violence in United States
#
# ---
#
# Project Team 4 <br>
# **Team Members**: [Bharati Malik](https://github.com/bharatimalik), [Gaurav Hassija](https://github.com/gauravhassija), [Prachi Sharma](https://github.com/Psharma2193), [Shruti Trivedi](https://github.com/strivedi2), [Vikita Nayak](https://github.com/VikitaNayak)

# %% [markdown]
# ## Introduction
# This project is inspired by the [Vox article](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts) on America's unique **Gun Violence** problem. The article provides 17 maps and charts that represent various aspects of Gun ownership in United States. <br>
#
# According to the article, United States is an exceptional country where the right to bear arms is constitutionally protected. As a result of easy access to firearms, US also is the most homicidal among all developed countries ([Human Development Index, 2012 ](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts)). <br>
#
# In this project we have tried to explore relationships between deaths due to gun violence incidents, gun ownership rates and effect of laws related to gun ownership across states in US.
#
# Here is a **[link to our video](https://www.youtube.com/watch?v=Kf2dDp-myYo&feature=youtu.be)**  summarizing the findings from this project.

# %% [markdown]
# ##Findings
#
# Let us take a look at the key findings from our project. These findings were generated by analyzing a gun violence incident dataset available in [Kaggle](https://www.kaggle.com/jameslko/gun-violence-data/downloads/gun-violence-data.zip/1) which contains records of incidents ranging from 2013 to 2017.

# %% [markdown]
# ### Insight 1.  Suicides are the leading cause of deaths, causing over 70% of deaths due to Gun Violence incidents across United States.

# %% [markdown]
# In this first finding, we tried to understand type of deaths due to gun violence incidents - Suicides, Mass shooting deaths and Accidental deaths.
# <br>
# In the chart below we see that suicides contribute to over 70% deaths that occur due to gun violence.
#
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/PieChart.png" style="width:800px;"/>
#
# The original visualization can be accessed [here](https://public.tableau.com/profile/shruti8609#!/vizhome/GunVIolenceUnitedStates2017-FinalVersion/GunownershipandresultingdeathsUS2017).
#
# While the above pie chart shows data only for 2017, we found the same trend across 2014 - 2016 (years for which complete data was available). We have included those charts in the Making Of section.

# %% [markdown]
# **Even when looking at the state level, Suicides continue to be the leading cause of deaths across all states.**
# <br>
# In this chart we have tried to analyse the above trend across states in US and we see that suicides lead to the highest number of deaths from gun violence incidents across all the states.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/Deaths.png" style="width:800px;"/>
#
# Original visualization can be accessed [here](https://public.tableau.com/profile/shruti8609#!/vizhome/shared/R6BTSRN8P). In the original visualization, view can be filtered by state to see deaths in each state.

# %% [markdown]
# ### Insight 2. Increase in gun ownership rate, leads to increase in likelihood of death by suicides by ~ 170%

# %% [markdown]
# The following chart shows how number of average deaths increase with increase in gun ownership rates across United States. <br>
# **Increase in gun ownership also results in over 1000% increase in the likelihood of accidental death.**
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/GunOwnershipRate.png" style="width:800px;"/>
#
# Original visualization can be accessed [here](https://public.tableau.com/profile/shruti8609#!/vizhome/shared/B3FTP6CWY).

# %% [markdown]
# ### Insight 3. Increase in restrictive laws for gun ownership results in decrease in suicide deaths from gun violence incidents
#
# States with more restrictive laws, see fewer instances of suicide deaths due to gun violence incidents as compared to states with more permissive laws
#
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/GunLaws_SuicideDeaths.png" style="width:800px;"/>
#
#
# Original visualization can be accessed [here](https://public.tableau.com/profile/prachisharma#!/vizhome/AnalysisofStateGunLawsSuicideDeathfromGunviolenceincidents/Dashboard1).

# %% [markdown]
# ## Making of the visualizations
#
# The visualizations seen above and in this section, have been created using Tableau.

# %% [markdown]
# ### Visualizations for Insight 1: Suicides are the leading cause of deaths, causing over 70% of deaths due to Gun Violence incidents across United States.

# %% [markdown]
# #### Gun deaths across States, 2017
# The visualizations that were a part of this analysis were actually created in the final version. Working on the previous versions of this project gave us a general idea that most gun violence incidents result in suicides, but as part of this analysis we wanted to compare the total number of deaths due to Suicides with Mass shootings and Accidental deaths across US states.
#
# As first part of this analysis, we created a bar chart to compare the number of deaths across states.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/BarChart_makingof.png" style="width:800px;"/>

# %% [markdown]
# For this chart, we fixed y-axis scale for Mass Shootings deaths and Accidental deaths to  start from 0 and end at 3 (same as the y -axis for Suicide deaths) to ensure that the comparison is across a uniform scale.  This also helps improve the quality of the visualization by adjusting the bar sizes these charts.
#
# In the next step, we created indicators as separate charts each for -Suicide Deaths, Accidental Deaths and Mass Shooting Deaths and formatted the text to include same color scheme as used in the state wise chart above.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/SuicideDeaths.png" style="width:800px;"/>
#
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/AccidentalDeaths.png" style="width:800px;"/>
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/MSDeaths.png" style="width:800px;"/>

# %% [markdown]
# We finally created a dashboard to combine all the above charts. The dashboard became part of our Insight 1.
#
# The image of the same dashboard below is filtered by 'Louisiana' state to show that filter feature is also available in our visualization.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/StatewideDeaths_filteredview.png" style="width:800px;"/>

# %% [markdown]
# #### Making of Pie Chart
#
# Once the above dashboard was finalized, we decided to create a pie chart showing the total deaths by suicides, mass shootings and accidental deaths using 2017 data. Thus we could see that nearly 70% of deaths due to gun violence incidents are suicides. We wanted to really highlight this fact and make this our first insight. This is relevant because suicides are often not part of the debate in gun violence. They are overshadowed by incidents of mass shootings which always gather more media and public attention.
#
# Since our pie chart was only from 2017 data, we wanted to show that this was a consistent trend that was observed for years 2014 to 2017 (for which complete data was available in our dataset).
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/PieChart_MakingOf.png" style="width:800px;"/>
#
# In the above chart, while one can see that proportion of suicide deaths is consistently in the range of 70% across all years of analysis, we decided not to include this chart in the insight since a lot of pie charts would take the focus away from the original argument. In addition, all our other charts are using 2017 data so we wanted to ensure consistency across multiple charts.

# %% [markdown]
# ### Visualizations for Insight 2: Increase in gun ownership rate, leads to increase in likelihood of death by suicides by ~ 170% and increase in accidental deaths by over 1000%
#
# For this chart we originally started with the idea of understanding relationship between Gun Ownership and Gun violence related deaths across states in US, 2017.
# <br>
# Chart 5 on Vox website, originally created by Mother Jones, shows that there is a direct relationship between gun ownership and gun violence using data for 2013.
# For our analysis, we started with recreating the same chart using data from 2017.
#
# In Tableau we loaded our cleaned csv file ( output from the Data cleaning section covered in the next section), and created a table to aggregate number of people killed in gun violence incidents by state in 2017. We also added Total Guns and Population columns (these columns already contain 2017 data) to this table view and exported the data as a csv file.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/Crosstab.png" style="width:100px;"/>
#
# We then loaded this csv as a new data source in our Tableau file and created two new calculated fields for normalization:
#
# 1. Gun Deaths per 100,000 people: (N Killed / Avg. Population (2017)) * 100,000
# 2. Guns per 100 people: (Avg. Total guns / Avg. Population (2017)) * 100

# %% [markdown]
# #### Scatter Plots from first version
# We then created a scatter plot between Gun Deaths per 100,000 people and Guns owned per 100 people which initially did not reveal a significant trend due to Wyoming being an outlier state.
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/Gundeaths_gunownership.PNG" style="width=100px;"/>

# %% [markdown]
#  In the chart, Wyoming is an outlier with ~23 guns per 100 people and 1.5 deaths per 100,000 people. Due to this outlier, the trend represented in the Mother Jones chart could not be seen.
# <br>
#
# We then created a set to group non-outlier states to see if we can plot a significant trend line. Scroll down to see the final output.

# %% [markdown]
# **Suicide related deaths with gun ownership**
#
# In our [first version](https://github.com/strivedi2/Gun-Violence-in-United-States/blob/master/Gun_Violence_v1_Team4.ipynb), we also explored the same trend with Mass shooting and Suicides incidents.
#
# In the original chart, we had compared two scatter plots - one with relationship of mass shootings and another with suicides to see if we could see the same relationship as gun violence deaths.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/gundeaths_massshootings.PNG" style="width=100px;"/>
#
# In the above chart, while we observed a significant trend for mass shootings, we did not see a trend for suicides due to some outlier states.
#
# For this version, we have focussed our analysis only on **Suicide deaths**.
# In order to see if a trend indeed existed without the outliers, we created a set of non-outlier states and plotted a trend line.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/ScatterPlots.png" style="width:800px;"/>
#
# In the first chart, one can see that with increase in gun ownership, number of deaths due to gun violence incidents increases. This trend is represented by the blue line.
# <br>
# In the second chart, we see the same trend replicated across suicides if we remove the outliers.
#
# While the charts show a significant trend, we decided not to use them for our findings due to the outlier states and the skepticism that it could potentially generate for the trend that we have tried to show.

# %% [markdown]
# #### Gun Ownership Rate vs Average deaths
# Inspired from this chart, we next explored the relationship between the average number of deaths that occur against gun ownership rates in the first version.
# <br>
# We created multiple bins for gun ownership rates and plotted that against average number of deaths due to suicides, mass shootings and accidental deaths.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/GunOwnershipRate_Part1.png" style="width:800px;"/>

# %% [markdown]
# From the chart one can see that with increase in gun ownership, there is an increased rate in suicide and accidental deaths.
# The chart has been filtered to contain gun ownership between 0 - 3 per 100 people since those bins have an equal number of states. The remaining bins with upto 3 - 23 guns per 100 people have been filtered out due to lack of adequate data.
#
# Focussing our analysis on gun ownership between 0-3 guns per 100 people, we see that access and no access to a gun i.e. going from between 0 to 1 and t to 1.5 guns increases the likelihood of death by suicide by 170% and also increases chances of death by 1114%.
#
# **We found this to be a more _persuasive chart_ as compared to the scatter plots,** created above. This chart very clearly shows the percent increase in death with increase in gun ownership rates.

# %% [markdown]
# **For this version**, we have edited the above chart to focus only on Suicides and Accidental Deaths, since Mass shooting deaths are not something that can be controlled by an individual.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/GunOwnershipRate.png" style="width:800px;"/>
#
# We have removed the filter for average guns owned since that did not add any value to the chart. Gun ownership rates greater than 3% were observed only across 6 states, which are not significant to the analysis.
#
# We have also edited alias names in the x-axis to reflect the right ownership bins in our final version as compared to this chart. Since 1% gun ownership rate falls in the 1 to 1.5 category we did not want the audience to be misled by the x-axis in this chart. We have also provided an explanation for the bins under Data Analysis for Insight 1 and 2 in the next section.

# %% [markdown]
# **Making of the chart in Tableau**<br>
# Some key steps involved while making the chart in Tableau include:
# 1. Renaming the bin labels from [0.0 , 1.0] to 0 to 1. Here it is important to understand that ownership rates of 1% are not considered in this bin and are part of the second bin.
# 2. Adding a calculation of Percent Change in tooltip to show the change in percentage deaths from one ownership bin to the next.
# 3. Adding annotations for gun ownership at 1% which show the most significant increase in suicide and accidental deaths.
#
# Here we understand that the 1 to 1.5 and 1.5 to 2 bins can be confusing for the audience. But even to the normal eye, it is clearly visible that even a 0.5 increase in gun ownership increases likelihood of death by suicide.

# %% [markdown]
# ### Visualizations for Insight 3: Increase in restrictive laws for gun ownership results helps decrease instances of deaths due to gun violence incidents.

# %% [markdown]
# #### State's Gun Deaths & Stringency Score Analysis

# %% [markdown]
# In the first version of our analysis, we focused on identifying any possible relationships between Gun deaths and Gun laws incorporated in each state. We took State Firearm Law Database compiled by [RAND Corporation](https://www.rand.org/pubs/tools/TL283.html) as part of the Gun Policy in America initiative.
#
# For our analysis, we derived Stringency score to hold essence of both Restrictive and Permissive. It essentially depicts how stringent or strict the laws are in any given state.
#
#   **Stringency Score = No. of Restrictive laws - No. of Permissive laws**
#
# A positive Stringency Score infers that the state has more Restrictive laws in comparison to Permissive laws which implies that the State authorities hold a very strong opinion in controlling the Gun incidents through policy changes.
#
# On the other hand, a negative Stringency Score infers that state is lenient towards Guns incidents.

# %% [markdown]
# **Preliminary Analysis**- To identify if there is any underlying relationship between the Gun deaths Per 100K and Stringency Score (restrictiveness of the policies in state) we started with a correlation plot. There was no apparent relationship visible from the chart.  We could see the outlier in the data like California that has the highest number of restrictive laws and District of Columbia that has the highest number of Gun deaths per 100K.
#
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/GunDeaths_StringencyScore_PriAnalysis.PNG" style="width:800px;"/>

# %% [markdown]
# In our earlier version the chart below was presented as one of the key insights. The visualization did help us identify a relationship despite the presence of outliers.
#
# For states with higher gun deaths we see that the gun laws are more permissive, apart from a couple of outliers in the data (District of Columbia, Maryland and Illinois). The visible trend here is Gun Deaths are low for states with stricter Gun Laws, except a few outliers.
#
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/GunDeathsVsGunLaws_V1.PNG" style="width:800px;"/>

# %% [markdown]
# #### State's Suicide Deaths Analysis

# %% [markdown]
# As 70% of the Gun Violence related deaths are due to Suicides, we refined our analysis by focussing on Suicide Deaths.
#
# In our previous analysis, we saw that stringency score calculation was giving both positive and negative values.
#
# For this version, we experimented with elimination of negative values by taking only the ratio of Restrictive laws for each State with the total number of laws of that State. We did this in an attempt to see if there is a more prominent trend visible with ratio values.

# %% [markdown]
# We also normalized Suicide deaths by the population from the State dataset.

# %% [markdown]
# We performed two more calculations for deriving the below visualization:
#
# *   Suicide Deaths Normalized = Suicide Deaths / Population in 2017 * 100000
# *   Restrictive Percentage = Number of Restrictive laws for each State / Total laws for the State

# %% [markdown]
# Below is the visualization created for Normalized Suicide deaths and Restrictive percentage.
#
# From this chart, it became hard to detect any possible trend which was being better communicated in the previous version. We also can't see the effect of Restrictive Percentage on outliers. The Percentage measure is not providing any insight into relationship between Restrictive gun laws and number of Suicide Deaths for each State.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/State_Suicide_Deaths_Restrictive_Percentage.JPG" style="width:800px;"/>

# %% [markdown]
# ***For the final version,*** we decided to retain the original Stringency Score and not the Restrictive ratio as it was more visually intutive.  By taking the Stringency Score, we can see the outliers are clearly visible. Green color in the Stringency score denotes positive Stringency score(more Restrictive laws) and brown color denotes negative Stringency score(more Permissive laws). The change that we made for this version was to focus our analysis on Suicide deaths in States.

# %% [markdown]
# The visualization below clearly brings out the relationship by juxtaposing State Gun laws Stringency score with reported Suicide deaths. The visualization conveys the fact that states with stricter gun laws saw lesser suicide deaths.

# %% [markdown]
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/FinalVersion_Images/GunLaws_SuicideDeaths.png" style="width:800px;"/>

# %% [markdown]
# ## Data: Collection, Cleaning and Exploratory Analysis

# %% [markdown]
# ###Search for relevant data
#
# We were interested in exploring Gun ownership within each state and its relationship with suicide rates, mass shootings and officer involved shootings. After going through various sources of data, we were directed to [Gun Violence Archive](https://www.gunviolencearchive.org/). As the website states, it is an online archive of gun violence incidents collected from over 2,500  law enforcement, media, government and commercial sources daily in an effort to provide near-real time data about the results of gun violence.
#
# However, the data available for download on the website is limited by the number of rows and attributes that can  be exported as CSV. This led us to a larger and richer dataset on [Kaggle](https://www.kaggle.com/jameslko/gun-violence-data/downloads/gun-violence-data.zip/1).

# %%
import pandas as pd
import numpy as np
import altair as alt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns',200)
pd.set_option('display.max_rows',200)
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# ### Dataset 1: Gun Violence Dataset on Kaggle
# We downloaded the gun violence dataset available on [Kaggle](https://www.kaggle.com/jameslko/gun-violence-data/downloads/gun-violence-data.zip/1). This dataset has been taken from the same website [Gun Violence Archive](https://www.gunviolencearchive.org) using web scraping with Python script (_We could not get access to the script_).
#
# The dataset has a record of more than **260,000 gun violence incidents** between **Jan 2013 - March 2018**.
#
# In addition to incident date, state, address and number of people injured and killed; the dataset also contains information about the **type of incident** (such as mass shootings, suicides, officer involved shootings etc.), **guns involved** and **participant information including age, gender** etc. which makes this a richer dataset when compared to reports available on  [Gun Violence Archive](https://www.gunviolencearchive.org).

# %% [markdown]
# ### Preliminary Data Cleaning using MS Excel
#
# In preliminary analysis of the dataset, following columns were deleted in the csv file before uploading on github as they were not relevant to our analysis.
#
#
# *   Address, location description : We decided to retain State, City, Latitude and longitude for each incident and  believe address is not pertinent to our analysis.
#
# *   In addition URL columns directing to source of incident were also deleted.
#
#
#
#
# Next, separate csv files were created for each year from 2013 - 2018 (to satisfy the 25MB file limit on github)and uploaded on [GitHub](https://github.com/strivedi2/Gun-Violence-in-United-States).  We read those files in the following lines of code.

# %%
guns_2013 = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/gun-violence-2013.csv')
guns_2014 = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/gun-violence-2014.csv')

# %%
guns_2015 = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/gun-violence-2015.csv')
guns_2016 = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/gun-violence-2016.csv')
guns_2017 = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/gun-violence-2017.csv')
guns_2018 = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/gun-violence-2018.csv')

# %% [markdown]
# We concatenated the above dataframes to create a single dataframe.

# %%
guns_df = guns_2013.append([guns_2014,guns_2015,guns_2016,guns_2017,guns_2018])

# %% [markdown]
# We then checked for total number of columns and rows and identify if there are any columns with very high number of null values.

# %%
guns_df.shape
# Out:
# (239677, 19)

# %%
# To check for null values in the dataset
guns_df.isna().sum()
# Out:
# incident_id                 0
# date                        0
# state                       0
# city_or_county              0
# n_killed                    0
# n_injured                   0
# congressional_district      11944
# gun_stolen                  99498
# gun_type                    99451
# incident_characteristics    326
# latitude                    7923
# longitude                   7923
# n_guns_involved             99451
# participant_age_group       42119
# participant_gender          36362
# participant_status          27626
# participant_type            24863
# state_house_district        38772
# state_senate_district       32335
# dtype: int64

# %% [markdown]
# ### Data Cleaning in Python

# %% [markdown]
# **Drop columns with high null values** <br>
# We dropped columns where the null values were greater than 90,000 since we believe they will not be relevant to our analyses. <br>
# We also dropped column participant_status since the same data is available in numeric form in n_killed and n_injured columns.

# %%
guns_df.drop(columns =['gun_stolen','gun_type','n_guns_involved','participant_status'], inplace = True)

# %% [markdown]
# At this stage, the dataframe has following columns

# %%
guns_df.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'n_killed',
#        'n_injured', 'congressional_district', 'incident_characteristics',
#        'latitude', 'longitude', 'participant_age_group', 'participant_gender',
#        'participant_type', 'state_house_district', 'state_senate_district'],
#       dtype='object')

# %%
guns_df.head(2)
# Out:
#    incident_id    date         state city_or_county  n_killed  n_injured  \
# 0  461105       1/1/13  Pennsylvania  Mckeesport     0         4
# 1  460726       1/1/13  California    Hawthorne      1         3
#
#    congressional_district  \
# 0  14.0
# 1  43.0
#
#                                                                                                                                                                                                                      incident_characteristics  \
# 0  Shot - Wounded/Injured||Mass Shooting (4+ victims injured or killed excluding the subject/suspect/perpetrator, one location)||Possession (gun(s) found during commission of other crimes)||Possession of gun by felon or prohibited person
# 1  Shot - Wounded/Injured||Shot - Dead (murder, accidental, suicide)||Mass Shooting (4+ victims injured or killed excluding the subject/suspect/perpetrator, one location)||Gang involvement
#
#    latitude  longitude  \
# 0  40.3467  -79.8559
# ...

# %% [markdown]
# We have created Date Fields from the date column to help us plot yearly, monthly or weekly gun violence trends.

# %%
# Creating Date fields 

guns_df['date'] = pd.to_datetime(guns_df['date'])
guns_df['year'] = guns_df['date'].dt.year
guns_df['month'] = guns_df['date'].dt.month
guns_df['monthday'] = guns_df['date'].dt.day
guns_df['weekday'] = guns_df['date'].dt.weekday

# %% [markdown]
# ### **Understanding types of gun violence incidents**
#
# We wanted to categorize each incident into - **Mass Shooting, Suicide and Accidental Shootings**
#
# We checked for above keywords in the incident_characteristics column. We created new columns to indicate 1 if it was a Mass Shooting and 0 if not. Same approach was followed for Suicide and Accidental Shooting columns.

# %%
# New columns for Mass Shootings, Suicides, Accidental Shooting in original dataframe

guns_df['Mass_Shooting'] = guns_df['incident_characteristics'].str.contains("Mass Shooting") * 1.0

guns_df['Accidental_Shootings'] = guns_df['incident_characteristics'].str.contains("Accidental Shooting") * 1.0

guns_df['Suicide'] = guns_df['incident_characteristics'].str.contains("Suicide") * 1.0

# %%
# Drop columns incident_characterstics
guns_df.drop(columns ='incident_characteristics', inplace = True)

# %%
guns_df.columns
# Out:
# Index(['incident_id', 'date', 'state', 'city_or_county', 'n_killed',
#        'n_injured', 'congressional_district', 'latitude', 'longitude',
#        'participant_age_group', 'participant_gender', 'participant_type',
#        'state_house_district', 'state_senate_district', 'year', 'month',
#        'monthday', 'weekday', 'Mass_Shooting', 'Accidental_Shootings',
#        'Suicide'],
#       dtype='object')

# %% [markdown]
# ### Overall trend of gun violence incidents

# %%
# Plotting yearly trend of gun violence incidents in United States
alt.Chart(guns_df.groupby('year')['incident_id'].count().reset_index()).mark_line().encode(
    alt.X('year:O', title = 'Year'),
    alt.Y('incident_id', title = 'Total number of gun violence incidents')
).properties(
    title = 'Trend of gun violence incidents, Jan. 2013 - Mar. 2018',
    width=600).configure_axis(
    grid=False
)
# Out:
# Chart({
#   config: Config({
#     axis: AxisConfig({
#       grid: False
#     })
#   }),
#   data:    year  incident_id
#   0  2013  278
#   1  2014  51854
#   2  2015  53579
#   3  2016  58763
#   4  2017  61401
#   5  2018  13802      ,
#   encoding: FacetedEncoding({
#     x: X({
#       shorthand: 'year:O',
#       title: 'Year'
#     }),
#     y: Y({
#       shorthand: 'incident_id',
#       title: 'Total number of gun violence incidents'
#     })
#   }),
#   mark: 'line',
#   title: 'Trend of gun violence incidents, Jan. 2013 - Mar. 2018',
#   width: 600
# })

# %% [markdown]
# **Number of mass shootings by state.**

# %%
alt.Chart(guns_df.groupby('state')['Mass_Shooting'].count().reset_index()).mark_bar().encode(
    alt.X('state', title = 'State', 
         sort=alt.EncodingSortField(
            field="Mass_Shooting",
            op="sum",
            order="descending"
        )),
    alt.Y('Mass_Shooting', title = 'Total number of mass shootings')
).properties(
    title='Number of mass shootings by state (2013-2018)',
    width=650,
    height=400
).configure_axis(
    grid=False
)
# Out:
# Chart({
#   config: Config({
#     axis: AxisConfig({
#       grid: False
#     })
#   }),
#   data:                    state  Mass_Shooting
#   0   Alabama               5470
#   1   Alaska                1349
#   2   Arizona               2325
#   3   Arkansas              2841
#   4   California            16289
#   5   Colorado              3199
#   6   Connecticut           3064
#   7   Delaware              1685
#   8   District of Columbia  3191
#   9   Florida               15020
#   10  Georgia               8922
#   11  Hawaii                288
#   12  Idaho                 661
#   13  Illinois              17506
#   14  Indiana               5835
#   15  Iowa                  2511
#   16  Kansas                2145
#   17  Kentucky              4148
#   18  Louisiana             8083
#   19  Maine                 907
#   20  Maryland              5792
#   21  Massachusetts         5976
#   22  Michigan              6113
#   23  Minnesota             2405
# ...

# %% [markdown]
# ### **Limitations in the Dataset**

# %% [markdown]
# One of the challenges encountered in our analysis were caused by how the gun violence incidents were recorded in the dataset. Each entry in the dataset identifies an incident. Hence essential columns like Age, Participant type(suspect or victim), Gender were recorded in group.
#
#
#
# Participant Gender  | Participant Type
# --- | ---
# 0::Male\|1::Male\|2::Male\|3::Female | 0::Victim\|1::Victim\|2::Victim\|3::Subject-Suspect
#
#
# The challenge was to map these columns with each other to derive insights. For instance to know the Age of a particular participant like Suspect of the incident required valid mapping. Each record had different number of participants which made the extraction of the values even difficult.
#
# For analyzing the profile of Victims and Suspects we followed approach taken in this  [Kaggle Kernel](https://www.kaggle.com/shivamb/deep-exploration-of-gun-violence-in-us).

# %%
## Function for converting the values in form of key, value pair
def get_user_mapping(txt):
    if txt == "NA":
        return {}
    mapping = {}
    for d in txt.split("||"):
        try:
            key = d.split("::")[0]
            val = d.split("::")[1]
            if key not in mapping:
                mapping[key] = val
        except:
            pass

    return mapping

# %%
# Creating mapped columns for participants age group, type and gender
guns_df['participant_type'] = guns_df['participant_type'].fillna("NA")
guns_df['participant_type_map'] = guns_df['participant_type'].apply(lambda x : get_user_mapping(x))
guns_df['participant_age_group'] = guns_df['participant_age_group'].fillna("NA")
guns_df['participant_age_map'] = guns_df['participant_age_group'].apply(lambda x : get_user_mapping(x))
guns_df['participant_gender'] = guns_df['participant_gender'].fillna("NA")
guns_df['participant_gender_map'] = guns_df['participant_gender'].apply(lambda x : get_user_mapping(x))

# %% [markdown]
# ### **Understanding Gun Violence Suspects Profile**
#
# We wanted to analyze age and gender of suspects and victims of gun violence to identify any significant trends/insights.
#
#
# For analyzing the profile of Victims and Suspects we followed approach taken in this  [Kaggle Kernel](https://www.kaggle.com/shivamb/deep-exploration-of-gun-violence-in-us).

# %%
## Finding the Suspect Age Groups
suspect_age_groups = {}
for i, row in guns_df.iterrows():
    suspects = []
    for k,v in row['participant_type_map'].items():
        if "suspect" in v.lower():
            suspects.append(k)
    for suspect in suspects:
        if suspect in row['participant_age_map']:
            ag = row['participant_age_map'][suspect]
            if ag not in suspect_age_groups:
                suspect_age_groups[ag] = 0 
            else:
                suspect_age_groups[ag] += 1

# %%
# Plotting suspects age distribution
source = pd.DataFrame({
    'a': list(suspect_age_groups.keys()),
    'b': list(suspect_age_groups.values())
})
alt.Chart(source).mark_bar(size = 80).encode(
    alt.X('a:N', title='Age Group', 
         sort=alt.EncodingSortField(
            field="b",
            op="sum",
            order="ascending"
        )),
    alt.Y('b:Q', title = 'Number of Suspects',axis=alt.Axis(format='s')),
    tooltip = ("b")
).properties(
    title='Suspects: Age Distribution',
    width=400,
    height=400
).configure_axis(
    grid=False
)
# Out:
# Chart({
#   config: Config({
#     axis: AxisConfig({
#       grid: False
#     })
#   }),
#   data:             a       b
#   0  Adult 18+   151071
#   1  Teen 12-17  12849
#   2  Child 0-11  577   ,
#   encoding: FacetedEncoding({
#     tooltip: Tooltip({
#       shorthand: 'b'
#     }),
#     x: X({
#       shorthand: 'a:N',
#       sort: EncodingSortField({
#         field: 'b',
#         op: 'sum',
#         order: 'ascending'
#       }),
#       title: 'Age Group'
#     }),
#     y: Y({
#       axis: Axis({
#         format: 's'
#       }),
#       shorthand: 'b:Q',
#       title: 'Number of Suspects'
#     })
#   }),
#   height: 400,
#   mark: MarkDef({
#     size: 80,
#     type: 'bar'
#   }),
#   title: 'Suspects: Age Distribution',
#   width: 400
# })

# %% [markdown]
# From the above chart we see that most incidents are carried out by adults older than 18 years but we also see a significant number of incidents involving teens aged 12-17 years.

# %%
## Finding the Suspect's Gender
suspect_gender = {}
for i, row in guns_df.iterrows():
    suspects = []
    for k,v in row['participant_type_map'].items():
        if "suspect" in v.lower():
            suspects.append(k)
    for suspect in suspects:
        if suspect in row['participant_gender_map']:
            g = row['participant_gender_map'][suspect]
            if g not in suspect_gender:
                suspect_gender[g] = 0 
            else:
                suspect_gender[g] += 1

# %%
source = pd.DataFrame({
    'a': list(suspect_gender.keys()),
    'b': list(suspect_gender.values())
})

alt.Chart(source).mark_bar(size = 80).encode(
    alt.X('a:N', title='Gender'),
    alt.Y('b:Q', title = 'Number of Suspects',axis=alt.Axis(format='s')),
    tooltip = ("b")
).properties(
    title='Suspects: Gender Distribution',
    width=400,
    height=400
).configure_axis(
    grid=False
)
# Out:
# Chart({
#   config: Config({
#     axis: AxisConfig({
#       grid: False
#     })
#   }),
#   data:         a       b
#   0  Female  11745
#   1  Male    167707,
#   encoding: FacetedEncoding({
#     tooltip: Tooltip({
#       shorthand: 'b'
#     }),
#     x: X({
#       shorthand: 'a:N',
#       title: 'Gender'
#     }),
#     y: Y({
#       axis: Axis({
#         format: 's'
#       }),
#       shorthand: 'b:Q',
#       title: 'Number of Suspects'
#     })
#   }),
#   height: 400,
#   mark: MarkDef({
#     size: 80,
#     type: 'bar'
#   }),
#   title: 'Suspects: Gender Distribution',
#   width: 400
# })

# %% [markdown]
# From the above chart we can see that most of the incidents are committed by Males.

# %% [markdown]
# ### Analysis on Gun ownership in US by state
# In the [article on Vox's website](https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts), chart 5 depicts the relationship between gun ownership and gun deaths across states in USA. The chart was created using 2013 data for gun ownership and gun deaths.
#
# Since we have more recent data (upto March 2018), we were interested in exploring this relationship with gun ownership data for a later time period. We found [2017 gun ownership by state](https://www.thoughtco.com/gun-owners-percentage-of-state-populations-3325153) as compiled by the website [HuntingMark.com](https://huntingmark.com/gun-ownership-stats/#_ftn1%20). The data on this website is taken from ATF (United States Department of Justice Bureau of Alcohol, Tobacco, Firearms and Explosives) report on [Firearm Commerce in the United States, 2017 statistics](https://www.atf.gov/resource-center/docs/undefined/firearms-commerce-united-states-annual-statistical-update-2017/download) **Exhibit 8** on **National Firearms Act Registered Weapons by State (April 2017)** which lists the number of registered guns by state.
#
# It is important to note that the actual number of guns might be much more than the numbers depicted here since United States does not have a regulation in place for registration of all guns. But this is the most reliable, if any, data source available to us on gun ownership so we decided to use this for our analysis.

# %%
# importing gun ownership data by state
state_guns_owned = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/Statewise_Gun_Ownership2017.csv')

# %%
state_guns_owned.head(2)
# Out:
#      State Any Other Weapon1 Destructive Device2 Machinegun3 Silencer4  \
# 0  Alabama  1,203             78,434              26,307      48,118
# 1  Alaska   327               4,722               1,650       6,040
#
#   Short Barreled Rifle5 Short Barreled Shotgun6    Total
# 0  5,285                 2,294                   161,641
# 1  1,783                 1,302                   15,824

# %% [markdown]
# In order to normalize gun ownership by state population we also decided to add state population data for 2017 from [here](https://www.enchantedlearning.com/usa/states/population.shtml).

# %% [markdown]
# We will now load state population data and create a new dataframe with total guns and population columns for each state for 2017.

# %%
# load state population dataset
state_pop = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/StatePopulation%202017.csv')
state_pop.head()
# Out:
#           State Population (2017)
# 0  California    39,536,653
# 1  Texas         28,304,596
# 2  Florida       20,984,400
# 3  New York      19,849,399
# 4  Pennsylvania  12,805,537

# %%
# merge gun ownership and state population dataframes
state_data = state_guns_owned.merge(state_pop, how ='inner', left_on='State', right_on='State')

# drop remaining gun type columns since we wont be using them for our analysis 
state_data.drop(columns=['Any Other Weapon1','Destructive Device2','Machinegun3','Silencer4','Short Barreled Rifle5','Short Barreled Shotgun6'],inplace=True)

# %%
state_data.head()
# Out:
#         State    Total Population (2017)
# 0  Alabama     161,641  4,874,747
# 1  Alaska      15,824   739,795
# 2  Arkansas    79,841   3,004,279
# 3  Arizona     179,738  7,016,270
# 4  California  344,622  39,536,653

# %% [markdown]
# We will now merge the above dataframe with our original dataset to add these columns.

# %%
guns_df = guns_df.merge(state_data, how='left', left_on='state', right_on='State')
guns_df.drop(columns='State',inplace=True)

# rename the Total column to Total_guns
guns_df.rename(columns={'Total':'Total_guns'},inplace=True)

# %% [markdown]
# ### Data dictionary of cleaned dataset: Gun Violence Dataset on Kaggle
# Column Name  | Description
# --- | ---
# incident_id | Incident ID
# date	| Date of crime (Format: YYYY-MM-DD)
# state	|State where crime was committed
# city_or_county	|City/ County of crime
# n_killed	|Number of people killed in the incident
# n_injured	|Number of people injured in the incident
# congressional_district |Congressional district id
# latitude	|Latitude of the location of the incident
# longitude	|Longitude of the location of the incident
# participant_age_group	|Age group of participant(s) (Child, Teen, Adult)
# participant_gender	|Gender of participant(s)
# participant_type	|Type of participant (Victim, Suspect)
# state_house_district	|Voting house district
# state_senate_district	|Territorial district from which a senator to a state legislature is elected
# year | Year of incident
# month | Month of incident
# monthday | Day of incident
# weekday | Day of the week of incident (Mon, Tue, etc.)
# Mass_Shooting | Incident characteristic: 1 means Mass Shooting
# Suicide | Incident characteristic: 1 means Suicide
# Accidental_Shootings | Incident characteristic: 1 means Shooting occured by Accident
# participant_type_map | Map Participant type
# participant_age_map | Map Participant age
# participant_gender_map | Map Participant gender
# Total_guns|Total guns owned in each State in 2017
# Population (2017)|Population of the State in 2017

# %% [markdown]
# ### Data Analysis for Insights 1 and 2

# %% [markdown]
# We will now calculate number of deaths occuring due to mass shootings, suicides and accidental shootings across states and compare the data.

# %%
# read state data for 2017
state = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/State%20data.csv')

state.rename(columns={"N Killed":'Gun_Deaths',
                     'Avg. Population (2017)': 'Population_2017',
                     'Avg. Total guns':'TotalGuns',
                     'Guns per 100 people': 'GunsPer100People'}, inplace=True)

# %%
#rename state column to State to ease merging columns with state dataframe
guns_df.rename(columns={'state':'State'}, inplace=True)

# %%
# calculate deaths due to Mass Shootings, Suicide and Accidental Shootings in 2017 

MS_deaths = guns_df.loc[(guns_df.Mass_Shooting == 1) & (guns_df.year == 2017)].groupby('State')['n_killed'].sum().reset_index().rename(columns={'n_killed':'MassShootingDeaths'})
Suicide_deaths = guns_df.loc[(guns_df.Suicide == 1) & (guns_df.year == 2017)].groupby('State')['n_killed'].sum().reset_index().rename(columns={'n_killed':'SuicideDeaths'})
Accidental_deaths = guns_df.loc[(guns_df.Accidental_Shootings == 1) & (guns_df.year == 2017)].groupby('State')['n_killed'].sum().reset_index().rename(columns={'n_killed':'AccidentalDeaths'})

# %%
# add the above dataframes as new columns in 'state' dataframe 

state = state.merge(MS_deaths, how='left', on='State')
state = state.merge(Suicide_deaths, how='left', on='State')
state = state.merge(Accidental_deaths, how='left', on='State')

# %%
# fill null values with 0 for states with no deaths in any of the columns
state.fillna(0,inplace=True)

# perform check for null values
state.isna().sum()
# Out:
# State                 0
# Gun_Deaths            0
# Population_2017       0
# TotalGuns             0
# GunDeathsPer100K      0
# GunsPer100People      0
# MassShootingDeaths    0
# SuicideDeaths         0
# AccidentalDeaths      0
# dtype: int64

# %% [markdown]
# In the next step we create bins for the columns 'GunsPer100People' to help group states by rate of gun ownership.

# %%
# create bins for rate of gun ownership
state['Gunsowned_range'] = pd.cut(state['GunsPer100People'], bins=[0,1,1.5,2,3,5,7,23])

state.groupby('Gunsowned_range')['State'].count()
# Out:
# Gunsowned_range
# (0.0, 1.0]     10
# (1.0, 1.5]     12
# (1.5, 2.0]     11
# (2.0, 3.0]     12
# (3.0, 5.0]     4
# (5.0, 7.0]     1
# (7.0, 23.0]    1
# Name: State, dtype: int64

# %% [markdown]
# As seen from above distribution, 23 states have gun ownership rates in the range of 1-2. In order to prevent any bias from being introduced in our analysis due to a large number of observations in one group, we decided to split the bin into 1 - 1.5 and 1.5 - 2.
#
# We are interested to see if there is any change due to the slight increase in gun ownership.

# %% [markdown]
# We then extract this data into our local system and load it as a data source on Tableau. We create normalized fields for deaths due to mass shootings, accidental shootings and suicides per 100,000 people.
#
# We then create a chart in Tableau to identify if there is any change in the number of deaths with increase in gun ownership rate across states.

# %% [markdown]
# In order to create the pie charts to study the number of deaths due to Suicides, Mass Shootings and Accidental Deaths, we grouped the above dataset by state and year to get data for different years in the following lines of code.

# %%
#calculate deaths due to Mass Shootings, Suicide and Accidental Shootings in 2013

MS_deaths_2013 = guns_df.loc[(guns_df.Mass_Shooting == 1) & (guns_df.year == 2013)]['n_killed'].sum()
Suicide_deaths_2013 = guns_df.loc[(guns_df.Suicide == 1) & (guns_df.year == 2013)]['n_killed'].sum()
Accidental_deaths_2013 = guns_df.loc[(guns_df.Accidental_Shootings == 1) & (guns_df.year == 2013)]['n_killed'].sum()

# calculate deaths due to Mass Shootings, Suicide and Accidental Shootings in 2014

MS_deaths_2014 = guns_df.loc[(guns_df.Mass_Shooting == 1) & (guns_df.year == 2014)]['n_killed'].sum()
Suicide_deaths_2014 = guns_df.loc[(guns_df.Suicide == 1) & (guns_df.year == 2014)]['n_killed'].sum()
Accidental_deaths_2014 = guns_df.loc[(guns_df.Accidental_Shootings == 1) & (guns_df.year == 2014)]['n_killed'].sum()

# calculate deaths due to Mass Shootings, Suicide and Accidental Shootings in 2015

MS_deaths_2015 = guns_df.loc[(guns_df.Mass_Shooting == 1) & (guns_df.year == 2015)]['n_killed'].sum()
Suicide_deaths_2015 = guns_df.loc[(guns_df.Suicide == 1) & (guns_df.year == 2015)]['n_killed'].sum()
Accidental_deaths_2015 = guns_df.loc[(guns_df.Accidental_Shootings == 1) & (guns_df.year == 2015)]['n_killed'].sum()

# calculate deaths due to Mass Shootings, Suicide and Accidental Shootings in 2016

MS_deaths_2016 = guns_df.loc[(guns_df.Mass_Shooting == 1) & (guns_df.year == 2016)]['n_killed'].sum()
Suicide_deaths_2016 = guns_df.loc[(guns_df.Suicide == 1) & (guns_df.year == 2016)]['n_killed'].sum()
Accidental_deaths_2016 = guns_df.loc[(guns_df.Accidental_Shootings == 1) & (guns_df.year == 2016)]['n_killed'].sum()

# calculate deaths due to Mass Shootings, Suicide and Accidental Shootings in 2017 

MS_deaths_2017 = guns_df.loc[(guns_df.Mass_Shooting == 1) & (guns_df.year == 2017)]['n_killed'].sum()
Suicide_deaths_2017 = guns_df.loc[(guns_df.Suicide == 1) & (guns_df.year == 2017)]['n_killed'].sum()
Accidental_deaths_2017 = guns_df.loc[(guns_df.Accidental_Shootings == 1) & (guns_df.year == 2017)]['n_killed'].sum()

# calculate deaths due to Mass Shootings, Suicide and Accidental Shootings in 2018

MS_deaths_2018 = guns_df.loc[(guns_df.Mass_Shooting == 1) & (guns_df.year == 2018)]['n_killed'].sum()
Suicide_deaths_2018 = guns_df.loc[(guns_df.Suicide == 1) & (guns_df.year == 2018)]['n_killed'].sum()
Accidental_deaths_2018 = guns_df.loc[(guns_df.Accidental_Shootings == 1) & (guns_df.year == 2018)]['n_killed'].sum()

# create data frame 
import pandas as pd

col_names =  ['Year','AccidentalDeaths', 'MassShootingDeaths', 'SuicideDeaths']
df  = pd.DataFrame(columns = col_names)
df.loc[len(df)] = [2013, Accidental_deaths_2013, MS_deaths_2013, Suicide_deaths_2013]
df.loc[len(df)] = [2014, Accidental_deaths_2014, MS_deaths_2014, Suicide_deaths_2014]
df.loc[len(df)] = [2015, Accidental_deaths_2015, MS_deaths_2015, Suicide_deaths_2015]
df.loc[len(df)] = [2016, Accidental_deaths_2016, MS_deaths_2016, Suicide_deaths_2016]
df.loc[len(df)] = [2017, Accidental_deaths_2017, MS_deaths_2017, Suicide_deaths_2017]
df

# Using the following code, the data frame file was downloaded locally and used to make Tableau visualizations.
#from google.colab import files

#df.to_csv('df.csv')
#files.download('df.csv')
# Out:
#    Year AccidentalDeaths MassShootingDeaths SuicideDeaths
# 0  2013  0                288                38
# 1  2014  365              265                2089
# 2  2015  436              366                1930
# 3  2016  509              456                1946
# 4  2017  467              378                2202

# %% [markdown]
# ### Dataset 2: RAND State Firearm Law dataset
#
# To take our analysis on the states a step further, we then tried to understand the role of policies on Gun related Incidents. For this we took State Firearm Law Database compiled by RAND Corporation as part of the Gun Policy in America initiative. RAND developed this longitudinal data set of state firearm laws that is free to the public, including other researchers, to support improved analysis and understanding of the effects of various laws. The Database contains information on state and District of Columbia firearm laws in the United States from 1979 to 2016. The database does not capture all firearm-related laws, only those of specific types.
#
# Here is a link to the [site](https://www.rand.org/pubs/tools/TL283.html )

# %% [markdown]
# The Dataset looks like this -

# %%
# read RAND state Law data

rand_state_df = pd.read_csv('https://raw.githubusercontent.com/Psharma2193/Individual-Project---First-Version/master/StateFirearmLaw.csv')

# %% [markdown]
# The dataset is rich in providing key insights into what type of law is implemented in each state, from when it has been effective etc. For our analysis our focus has been on innate Effect of the law i.e. whether it is Restrictive or Permissive in its nature.
#
# Example - Dealer licensing of handguns is Restrictive in Alabama whereas carrying a concealed weapon (CCW) is Permissive.

# %%
rand_state_df['Effect'].unique()
# Out:
# array([nan, 'Permissive', 'Restrictive'], dtype=object)

# %% [markdown]
# ### Data Cleaning in Python
#
# We extracted the Total number of Restrictive and Total number of Permissive for each state in a separate file to have aggregated values for these.

# %%
# read state Gun Law data

stringency_df = pd.read_csv('https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/state_stringency.csv')

# %%
stringency_df.head()
# Out:
#         State  Permissive  Restrictive
# 0  Alabama     5           5
# 1  Alaska      4           3
# 2  Arizona     4           5
# 3  Arkansas    2           3
# 4  California  2           27

# %% [markdown]
# This dataset was merged with the state dataset to analyze Gun incident in light of governing gun laws in each state.

# %%
#add the above dataframes as new columns in 'state' dataframe 

law_incident_df = state.merge(stringency_df, how='left', on='State')

# %% [markdown]
# ### Understanding the gun laws for each state
# As a preliminary analysis we roughly plotted the figures to get an idea of presenting a trend or pattern if any.

# %%
from IPython.display import Image
from IPython.display import Image,display
from IPython.core.display import display, HTML
display(HTML('<img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/Gun_Laws_Incidents_PriAnalysis.PNG" style="width:900px;"/>'))
# Out:
# <img src="https://raw.githubusercontent.com/strivedi2/Gun-Violence-in-United-States/master/Gun_Laws_Incidents_PriAnalysis.PNG" style="width:900px;"/>

# %% [markdown]
# From above graph we felt that instead of communicating two different parameters in form of Restrictive and Permissive, its more appropriate to have one derived field that holds the essence of both. Hence, we created a calculated field called Stringency Score to depict how stringent or strict the laws are in any given state.
# <br>
# <br>
# A positive Stringency Score infers that the state has more Restrictive laws in comparison to Permissive laws which implies that the State authorities hold a very strong opinion in controlling the Gun incidents through policy changes. On the other hand, a negative Stringency Score infers that state is lenient towards Guns incidents.

# %%
law_incident_df['Stringency_score'] = law_incident_df['Restrictive'] - law_incident_df['Permissive']

# %% [markdown]
# This dataset was then used to create the Visualizations in Tableau for this analysis.

# %% [markdown]
# **Limitation in the analysis**
#
# * We found that there are a lot of records that had null values in the Effects column. For some rows, a certain law we observed the Effect type was restrictive and at other places it was found to be null. This may have affected the analysis.
#
# * It's hard to classify the seriousness of each law that is defined as Restrictive or Permissive by a state authority. The Stringency score field only gives us insight into the weightage given to policies but it is subject to what state authorities deem as restrictive and permissive and this could be different for each state.

# %% [markdown]
# ### Data dictionary of cleaned dataset: RAND State Firearm Law Dataset
#
# Column Name  | Description
# --- | ---
# state	|State where crime was committed
# Gun_Deaths	|Number of deaths due to guns
# Population (2017)|Population of the State in 2017
# Total_guns|Total guns owned in each State in 2017
# GunDeathsPer100K|Number of deaths due to guns per 100K people
# GunsPer100People|Numberof guns owned per 100 people
# MassShootingDeaths|NUmber of deaths in mass shootings
# Suicide Deaths|Number of deaths due to suicide using guns
# AcciedntalDeaths|Number of accidental deaths using guns
# Permissive| Permissive score
# Restrictive| Restrictive Score
# Stringency_score| Stringency score of laws

# %% [markdown]
# We also tried to calculated Restrictive Percentage score for each state to avoid the negative values generated from the stringency score calculated above for this version. Below is the code used to generate Restrictive Percentage score for each state.

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Psharma2193/Individual-Project---First-Version/master/StateFirearmLaw.csv',index_col=0)

score_df = df[['State','Effect','Type of Change','Effective Date Year']]
score_df.dropna(inplace=True)

# %%
#Creating Total laws df for each State

score_effect_total = score_df.groupby('State')['Effect'].count().reset_index()

# %%
 #Creating Restrictive laws df for each state
  
score_df_effect=score_df[score_df.Effect=='Restrictive'].groupby(['State'])['Effect'].count().reset_index()

# %%
#Merging both the df's to caluculate Restrictive Percentage

state_laws = score_effect_total.merge(score_df_effect,on='State',how='left') 
state_laws['Restrictive_Percentage'] = (state_laws.Effect_y/state_laws.Effect_x)*100

state_laws.rename(columns={"Effect_x": "Total_laws","Effect_y": "Total_Restrictive_laws"},inplace=True)

# %% [markdown]
# ## Conclusion
#
#
#
# From the analysis we found that:
#
#
# **Suicides contribute to 70% of the total deaths that occur due to gun violence incidents across United States**
#
# We analyzed three causes of deaths due to gun violence incidents- suicidal deaths, accidental deaths & mass shooting deaths. We observed that over the time-period of our analysis (2014-2017), suicides comprise nearly two-thirds of all gun violence related deaths. We also saw that suicides are the leading cause of death from gun violence incidents across all states.
#
#
# This is an important finding becase gun violence related incidents gather public and media attention only when a mass shooting occurs in US. However, in our analysis we found that 70% of deaths due to gun violence incidents are suicides, and they are almost never a part of the public debate.
# <br>
#
#
# **Increase in gun ownership rates leads to increase in likelihood of deaths by suicides**
#
# We see that increase in gun ownership rate from 0% to 1% results in an increase in the number of average deaths by suicides by ~170%. Increase in gun ownership also increases likelihood of accidental death by over 1000%.
#
# This is an important finding because guns are often advertised and believed to be a means of protection and safety in US, but we clearly see that with increase in gun ownership rates, there is an increase in number of deaths- accidental or suicide.
# <br>
#
#
# **Restrictive laws do have an impact on suicides using guns. Increasing restrictive gun laws can reduce suicide deaths from gun violence incidents**
#
# The issue of gun violence is extremely complicated and varied across state laws and local culture. Many states support that strict firearm regulation is a necessary measure in preventing and reducing gun deaths; however, many other states do not take this stance.
#
# We could see that states with strict gun policies have fewer instances of suicide deaths when compared to states with lenient gun policies.
# This implies that restrictive laws are an important force that can help reduce number of suicide deaths across states.
# <br>
#
#
# To summarize, from our analysis, it is evident that suicides are the leading cause of deaths from gun violence incidents and increase in gun ownership rate leads to increase in number of suicide deaths. However, states can introduce more restrictive laws to help reduce incidents of suicides.

# %% [markdown]
# ## References
#
#
#
# 1.   Gun Violence Archive data: https://www.gunviolencearchive.org/
# 2.   Kaggle's gun violence data: https://www.kaggle.com/account/login?returnUrl=%2Fjameslko%2Fgun-violence-data%2Fversion%2F1
# 3.   Kaggle's link for suspect profile analysis: https://www.kaggle.com/shivamb/deep-exploration-of-gun-violence-in-us
# 4.   Vox article: https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts
# 5.  Gun owenership by state: https://www.thoughtco.com/gun-owners-percentage-of-state-populations-3325153
# 6.  Hunting mark data for gun violence:https://huntingmark.com/gun-ownership-stats/#_ftn1%20
# 7. Firearms states 2017 : https://www.atf.gov/resource-center/docs/undefined/firearms-commerce-united-states-annual-statistical-update-2017/download
# 8.  Dataset for normalization of the gunviolence dataset: https://www.enchantedlearning.com/usa/states/population.shtml
# 9.  RAND dataset for stringency score analysis: https://www.rand.org/pubs/tools/TL283.html
# 10. Data from human index: https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts
# 11. Gun Image in the video: https://www.newsclick.in/mass-shootings-gun-violence-and-pathology-us-terror-state
